# %%
import tensorflow as tf

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
from keras.datasets import mnist

# %%
object=mnist

# %%
(train_img,train_lab),(test_img,test_lab)=object.load_data()

# %%
for i in range(20):
    plt.subplot(5,4,i+1)
    plt.imshow(train_img[i],cmap='gray_r')
    plt.subplots_adjust(hspace=0.5)

# %%
plt.hist(train_img[0].reshape(784),facecolor='green')
plt.ylabel=('pixel')
plt.xlabel=('intensity')
plt.text(0.5,0,'intensity')
# Out:
# Text(0.5, 0, 'intensity')

# %%
train_img=train_img/255.0
test_img=test_img/255.0

# %%
plt.hist(train_img[0].reshape(784),facecolor='green')
plt.ylabel=('pixel')
plt.xlabel=('intensity')
plt.text(0.5,0,'intensity')
# Out:
# Text(0.5, 0, 'intensity')

# %%
from keras.models import Sequential
from keras.layers import Flatten,Dense
model=Sequential()
input_layer=Flatten(input_shape=(28,28))
model.add(input_layer)
hidden_layer1=Dense(512,activation='relu')
model.add(hidden_layer1)
hidden_layer2=Dense(512,activation='relu')
model.add(hidden_layer2)
output_layer=Dense(512,activation='relu')
model.add(output_layer)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_img,train_lab,epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 34s 18ms/step - loss: 5.4778 - accuracy: 0.1222
# Epoch 2/3
# 1875/1875 [==============================] - 33s 18ms/step - loss: 6.2383 - accuracy: 0.0987
# Epoch 3/3
# 1875/1875 [==============================] - 34s 18ms/step - loss: 6.2383 - accuracy: 0.0987

# %%
loss_and_acc=model.evaluate(test_img,test_lab,verbose=8)

# %%
print('test loss',loss_and_acc[0])
print('test accuracy',loss_and_acc[1])
# Out:
# test loss 6.238307476043701
# test accuracy 0.09799999743700027
